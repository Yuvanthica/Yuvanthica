# %%
import pandas as pd
import numpy as np
from scipy.stats import shapiro
from scipy.stats import stats

# %%
df = pd.read_excel('/content/data_bharath_2.xlsx')
df.head()
# Out:
#    PRE A  POST A  PRE B  POST B
# 0   12.0      19     16      13
# 1   14.0      10     14      10
# 2   17.0      12     17      14
# 3   19.0      13     14      11
# 4   18.0      13     15      12

# %%
shapiro(df)
# Out:
# (0.9829031229019165, 0.562752366065979)

# %%
df1 = df[['PRE A','POST A']]
df1
# Out:
#     PRE A  POST A
# 0    12.0      19
# 1    14.0      10
# 2    17.0      12
# 3    19.0      13
# 4    18.0      13
# 5    16.0      11
# 6    19.0      15
# 7    20.0      16
# 8    13.0      10
# 9    14.0      10
# 10   14.0       9
# 11   13.0       8
# 12   21.0      16
# 13   16.0      12
# 14   16.5      13

# %%
shapiro(df1)
# Out:
# (0.9726345539093018, 0.613484799861908)

# %%
df2 = df[['PRE B','POST B']]
df2
# Out:
#     PRE B  POST B
# 0      16      13
# 1      14      10
# 2      17      14
# 3      14      11
# 4      15      12
# 5      18      14
# 6      17      15
# 7      16      12
# 8      17      15
# 9      16      13
# 10     15      11
# 11     14      10
# 12     17      13
# 13     20      16
# 14     14      12

# %%
shapiro(df2)
# Out:
# (0.9752889275550842, 0.6912440657615662)

# %%
df.describe()
# Out:
#            PRE A     POST A      PRE B     POST B
# count  15.000000  15.000000  15.000000  15.000000
# mean   16.166667  12.466667  16.000000  12.733333
# std     2.800935   3.020564   1.732051   1.830951
# min    12.000000   8.000000  14.000000  10.000000
# 25%    14.000000  10.000000  14.500000  11.500000
# 50%    16.000000  12.000000  16.000000  13.000000
# 75%    18.500000  14.000000  17.000000  14.000000
# max    21.000000  19.000000  20.000000  16.000000

# %% [markdown]
# paired t test between pre tests A nd B

# %%
stats.ttest_rel(df1['PRE A'],df2['PRE B'])
# Out:
# Ttest_relResult(statistic=0.20877392182900978, pvalue=0.8376317947212442)

# %% [markdown]
# paired t test between post tests A nd B

# %%
stats.ttest_rel(df1['POST A'],df2['POST B'])
# Out:
# Ttest_relResult(statistic=-0.330235524225612, pvalue=0.7461118070740537)

# %% [markdown]
# independent t test within the group A

# %%
stats.ttest_ind(df1['PRE A'],df1['POST A'])
# Out:
# Ttest_indResult(statistic=3.4787131540790437, pvalue=0.00166612411701619)

# %% [markdown]
# independent t test between group A nd B (pre test)

# %%
stats.ttest_ind(df1['PRE A'],df2['PRE B'])
# Out:
# Ttest_indResult(statistic=0.19600846774871544, pvalue=0.8460191561614739)

# %% [markdown]
# independent t test between group A nd B (post test)

# %%
stats.ttest_ind(df1['POST A'],df2['POST B'])
# Out:
# Ttest_indResult(statistic=-0.2923973036915803, pvalue=0.7721386436459383)

# %% [markdown]
# independent t test within the group B

# %%
stats.ttest_ind(df2['PRE B'],df2['POST B'])
# Out:
# Ttest_indResult(statistic=5.019751094374628, pvalue=2.627539331560844e-05)

# %% [markdown]
# paired t test between group B

# %%
stats.ttest_rel(df2['PRE B'],df2['POST B'])
# Out:
# Ttest_relResult(statistic=15.838268411308626, pvalue=2.473457809607936e-10)

# %% [markdown]
# paired t test between group A

# %%
stats.ttest_rel(df1['PRE A'],df1['POST A'])
# Out:
# Ttest_relResult(statistic=4.6864236732203155, pvalue=0.00035006800363306145)
